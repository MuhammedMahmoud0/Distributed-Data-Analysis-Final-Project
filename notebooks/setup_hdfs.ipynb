# %%
import pandas as pd
import numpy as np
from pyspark.sql import SparkSession

# %%
file_path = "../data/online_retail.xlsx"
pdf1 = pd.read_excel(file_path, sheet_name="sheet1")
pdf1.to_csv("../data/online_retail_sheet1.csv", index=False)

# %%
pd.read_csv("../data/online_retail_sheet1.csv").to_parquet("../data/online_retail_sheet1.parquet", index=False)

# %%
pdf2 = pd.read_excel(file_path, sheet_name="sheet2")
pdf2.to_csv("../data/online_retail_sheet2.csv", index=False)

# %%
pd.read_csv("../data/online_retail_sheet2.csv").to_parquet("../data/online_retail_sheet2.parquet", index=False)

# %%
if 'spark' in locals():
    spark.stop()

spark = SparkSession.builder \
    .appName("HDFS Test") \
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/01 14:50:08 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df1 = spark.read.csv("../data/online_retail_sheet1.csv", header=True, inferSchema=True)

# %%
df1.write.mode("overwrite").parquet("hdfs://localhost:9005/user/muhammed_mahmoud/bronze/sheet1/online_retail_sheet1.parquet")

# %%
df2 = spark.read.csv("../data/online_retail_sheet2.csv", header=True, inferSchema=True)

# %%
df2.write.mode("overwrite").parquet("hdfs://localhost:9005/user/muhammed_mahmoud/bronze/sheet2/online_retail_sheet2.parquet")

# %%
spark.stop()
